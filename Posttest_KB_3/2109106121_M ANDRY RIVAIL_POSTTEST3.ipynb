# %% [markdown]
# # POSTTEST 3

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Snapchat_app_store_reviews.csv')
df.head()
# Out:
#    Unnamed: 0             userName  rating  \
# 0           0       Savvanananahhh       4
# 1           1        Idek 9-101112       3
# 2           2     William Quintana       3
# 3           3  an gonna be unkown😏       5
# 4           4           gzhangziqi       1
#
#                                               review  isEdited           date  \
# 0  For the most part I quite enjoy Snapchat it’s ...     False   10/4/20 6:01
# 1  I’m sorry to say it, but something is definite...     False  10/14/20 2:13
# 2  Snapchat update ruined my story organization! ...     False  7/31/20 19:54
# 3  I really love the app for how long i have been...     False  4/22/21 14:10
# 4  This is super frustrating. I was in the middle...     False  10/2/20 13:58
#
#                                          title
# 0                           Performance issues
# 1                               What happened?
# 2                   STORY ORGANIZATION RUINED!
# ...

# %% [markdown]
# <h6>1.GRAFIK BATANG<h6>

# %%
data_bar = df['rating'].value_counts()

# %%
plt.bar(x=data_bar.index, height=data_bar.values)
plt.title('Total Rating')
# Out:
# Text(0.5, 1.0, 'Total Rating')

# %% [markdown]
# <h6>2.HISTOGRAM<h6>

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['rating'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribusi Rating Snapchat')
plt.xlabel('Rating')
plt.ylabel('Jumlah Rating')
plt.show()

# %% [markdown]
# <h6>3.LINEPLOT<h6>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9560 entries, 0 to 9559
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9560 non-null   int64
#  1   userName    9560 non-null   object
#  2   rating      9560 non-null   int64
#  3   review      9560 non-null   object
#  4   isEdited    9560 non-null   bool
#  5   date        9560 non-null   object
#  6   title       9560 non-null   object
# dtypes: bool(1), int64(2), object(4)
# memory usage: 457.6+ KB

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
plt.figure(figsize=(15, 8))
plt.plot(df['date'])

plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# <h6>4.HEATMAP<h6>

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='YlGn')
plt.title('Heatmap Korelasai Antara Variabel Numerik')
plt.xlabel('Variabel')
plt.ylabel('Variabel')
plt.show()

# %% [markdown]
# <h6>5.PIE CHART<h6>

# %%
data_pie = df['rating'].value_counts().rename('rating').reset_index(name='id_count') 
data_pie
# Out:
#    index  id_count
# 0      4      2346
# 1      3      2171
# 2      5      1932
# 3      1      1879
# 4      2      1232

# %%
plt.pie(data_pie.id_count, labels=data_pie["index"], startangle=90,
autopct='%.1f%%', shadow= True,)
plt.title('rating')
plt.show()
